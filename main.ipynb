# %%
# !pip install -r requirements.txt
from warpdrive import WarpDrive


wd = WarpDrive()
print("Hello from original")
print("Hello 2")
dataset = wd.get_args(dataset)
wd.save_table(dataset)
wd.create_df(dataset)
